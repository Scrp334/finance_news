# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

music_data = pd.read_csv('music.csv')
#Split datasets
X = music_data.drop(columns=['Genre']) #input set
y = music_data['Genre'] # Output dataset .For the answer(contains predictions)

model = DecisionTreeClassifier()
model.fit(X,y)
predictions = model.predict([[21,1], [22,0]])
predictions
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
music_data
# Out:
#     Age  Gender      Genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1        Pop
# 4    28       1        Pop
# 5    30       1        Pop
# 6    31       1  Classical
# 7    33       1  Classical
# 8    35       1  Classical
# 9    20       0      Dance
# 10   23       0      Dance
# 11   25       0      Dance
# 12   26       0        RnB
# 13   28       0        RnB
# 14   30       0        RnB
# 15   31       0  classical
# 16   33       0  classical
# 17   35       0  classical
